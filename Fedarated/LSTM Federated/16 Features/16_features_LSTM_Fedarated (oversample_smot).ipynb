# %%
# prompt: mount

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GroupShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, cohen_kappa_score, matthews_corrcoef
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, BatchNormalization, LeakyReLU, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
from tensorflow.keras.backend import clear_session
import datetime
import csv
from tensorflow.keras.layers import Conv1D, BatchNormalization, LeakyReLU, MaxPool1D, Dropout, GlobalAveragePooling1D, Dense

# %%
# Check if GPU is available
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Enable mixed precision
tf.keras.mixed_precision.set_global_policy('mixed_float16')
# Out:
# Num GPUs Available:  1

# %%
# Load data
df = pd.read_csv("/content/drive/MyDrive/DHS/Diabetes/Data/India/Data Balance/oversample_smote.csv")

selected_columns = ['hv005', 'hv021', 'hv023', 'hv105', 'hv115', 'hv104', 'hv106', 'hml18',
                    'shb70', 'ha53', 'shb13', 'hv206', 'hv116', 'avg_sys', 'avg_dia', 'bmi']

# Split the data into features and target
X = df[selected_columns]
y = df['final_diabetes']

# Convert X and y to numpy arrays if they are not already
X = np.array(X)
y = np.array(y)

# Standardize the data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Reshape data for the CNN model
X = X.reshape((X.shape[0], X.shape[1], 1))

# %%
from keras.layers import Bidirectional, LSTM, Dropout

# Define the LSTM model architecture using a function
def lstmmodel(learning_rate=0.001, dropout_rate=0.3):
    clear_session()
    model = Sequential()

    model.add(Bidirectional(LSTM(128, return_sequences=True), input_shape=(16, 1)))
    model.add(Dropout(dropout_rate))

    model.add(Bidirectional(LSTM(64)))
    model.add(Dropout(dropout_rate))

    model.add(Dense(1, activation='sigmoid'))

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
# Evaluate the model
def evaluate_model(model, X_val, y_val):
    y_val_pred = model.predict(X_val)
    y_val_pred_binary = (y_val_pred > 0.5).astype(int)

    accuracy = accuracy_score(y_val, y_val_pred_binary)
    precision = precision_score(y_val, y_val_pred_binary)
    recall = recall_score(y_val, y_val_pred_binary)
    f1 = f1_score(y_val, y_val_pred_binary)
    roc_auc = roc_auc_score(y_val, y_val_pred)
    cm = confusion_matrix(y_val, y_val_pred_binary)
    specificity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
    kappa = cohen_kappa_score(y_val, y_val_pred_binary)
    mcc = matthews_corrcoef(y_val, y_val_pred_binary)

    metrics = [accuracy, precision, recall, f1, roc_auc, specificity, kappa, mcc, cm]
    return metrics

# %%
from sklearn.model_selection import StratifiedKFold

class FederatedData:
    def __init__(self, X, y, num_clients, test_size=0.2):
        self.X = X
        self.y = y
        self.num_clients = num_clients
        self.test_size = test_size
        self.partitions = []
        self.create_partitions()

    def create_partitions(self):
        skf = StratifiedKFold(n_splits=self.num_clients, shuffle=True, random_state=42)
        for train_index, test_index in skf.split(self.X, self.y):
            X_train, X_test = self.X[train_index], self.X[test_index]
            y_train, y_test = self.y[train_index], self.y[test_index]
            self.partitions.append((X_train, y_train, X_test, y_test))
            print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}")

    def get_training_and_validation_data(self, client_idx):
        if client_idx < 0 or client_idx >= len(self.partitions):
            raise ValueError(f"Invalid client index. Must be between 0 and {len(self.partitions) - 1}.")
        partition_X_train, partition_y_train, partition_X_test, partition_y_test = self.partitions[client_idx]
        X_train, X_val, y_train, y_val = train_test_split(partition_X_train, partition_y_train, test_size=0.2, stratify=partition_y_train, random_state=42)
        return X_train, X_val, y_train, y_val, partition_X_test, partition_y_test

# Initialize federated data
federated_data = FederatedData(X, y, num_clients=3)
# Out:
# Train shape: (949976, 16, 1), Test shape: (474988, 16, 1)
# Train shape: (949976, 16, 1), Test shape: (474988, 16, 1)
# Train shape: (949976, 16, 1), Test shape: (474988, 16, 1)

# %%
import os
import datetime
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import csv

# Custom CSV Logger
class CustomCSVLogger(tf.keras.callbacks.Callback):
    def __init__(self, filename, separator=',', append=False):
        self.sep = separator
        self.filename = filename
        self.append = append
        self.file = None
        self.writer = None
        self.keys = None
        super(CustomCSVLogger, self).__init__()

    def on_train_begin(self, logs=None):
        if not self.append and os.path.isfile(self.filename):
            os.remove(self.filename)
        mode = 'a' if self.append else 'w'
        self.file = open(self.filename, mode, newline='')
        self.writer = csv.writer(self.file, delimiter=self.sep)

    def on_epoch_end(self, epoch, logs=None):
        if self.keys is None:
            self.keys = sorted(logs.keys())
            self.writer.writerow(self.keys)
        row = [logs.get(key) for key in self.keys]
        self.writer.writerow(row)

    def on_train_end(self, logs=None):
        self.file.close()


# Initialize global model
input_shape = X.shape[1:]
global_model = lstmmodel()
num_clients = 3
local_epochs = 1

# CSV file to store performance metrics
csv_filename = "/content/drive/MyDrive/DHS/Diabetes/Data/India/Deep Learning/LSTM Federated/16 Features/LSTM_16_features_federated_learning_metrics.csv"
header = ['Local Epoch', 'Client', 'Accuracy', 'Precision', 'Recall', 'F1-Score', 'ROC AUC', 'Specificity', 'Kappa', 'MCC', 'Confusion Matrix']
with open(csv_filename, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)

# Federated training process
for local_epoch in range(1, local_epochs + 1):
    print(f"Local Epoch {local_epoch}:")
    client_models = []

    # Create a directory for the current local epoch
    epoch_dir = f"/content/drive/MyDrive/DHS/Diabetes/Data/India/Deep Learning/LSTM Federated/16 Features/epoch_{local_epoch}"
    os.makedirs(epoch_dir, exist_ok=True)

    for client in range(num_clients):
        X_train, X_val, y_train, y_val, X_test, y_test = federated_data.get_training_and_validation_data(client)
        client_model = lstmmodel()
        client_model.set_weights(global_model.get_weights())  # Initialize with global weights

        with tf.device('/GPU:0'):
            log_dir = os.path.join(epoch_dir, "logs/profile/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
            tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, profile_batch=0)
            csv_logger = CustomCSVLogger(os.path.join(epoch_dir, f"training_client_{client+1}_epoch_{local_epoch}.csv"))

            history = client_model.fit(
                X_train, y_train,
                epochs=50,  # Train for 10 epochs (as a placeholder, adjust as needed)
                batch_size=256,
                validation_data=(X_val, y_val),
                verbose=1,
                callbacks=[tensorboard_callback, csv_logger]
            )

        # Evaluate the client model
        client_metrics = evaluate_model(client_model, X_val, y_val)
        print(f"Client {client + 1} - Metrics after Local Epoch {local_epoch}: {client_metrics}")

        # Save client model performance to CSV
        with open(csv_filename, 'a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([local_epoch, client + 1] + client_metrics[:-1] + [np.array2string(client_metrics[-1], separator=',')])

        client_models.append(client_model)

    # Aggregating weights from client models to update global model
    global_weights = global_model.get_weights()
    new_weights = [client_model.get_weights() for client_model in client_models]

    averaged_weights = [np.mean(np.array([client_weight[layer] for client_weight in new_weights]), axis=0) for layer in range(len(global_weights))]
    global_model.set_weights(averaged_weights)

# Save the global model
global_model.save("/content/drive/MyDrive/DHS/Diabetes/Data/India/Deep Learning/LSTM Federated/16 Features/LSTM_16_features_global_model.keras")
# Out:
# Local Epoch 1:
# Epoch 1/50
#    6/2969 [..............................] - ETA: 33s - loss: 0.6309 - accuracy: 0.7188
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0099s vs `on_train_batch_end` time: 0.0294s). Check your callbacks.
# 2969/2969 [==============================] - 50s 13ms/step - loss: 0.1078 - accuracy: 0.9564 - val_loss: 0.0549 - val_accuracy: 0.9772
# Epoch 2/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0557 - accuracy: 0.9771 - val_loss: 0.0521 - val_accuracy: 0.9784
# Epoch 3/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0509 - accuracy: 0.9788 - val_loss: 0.0449 - val_accuracy: 0.9806
# Epoch 4/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0469 - accuracy: 0.9802 - val_loss: 0.0473 - val_accuracy: 0.9819
# Epoch 5/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0432 - accuracy: 0.9818 - val_loss: 0.0407 - val_accuracy: 0.9824
# Epoch 6/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0398 - accuracy: 0.9830 - val_loss: 0.0381 - val_accuracy: 0.9839
# Epoch 7/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0360 - accuracy: 0.9847 - val_loss: 0.0317 - val_accuracy: 0.9864
# Epoch 8/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0327 - accuracy: 0.9862 - val_loss: 0.0303 - val_accuracy: 0.9874
# Epoch 9/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0298 - accuracy: 0.9876 - val_loss: 0.0272 - val_accuracy: 0.9888
# Epoch 10/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0273 - accuracy: 0.9888 - val_loss: 0.0238 - val_accuracy: 0.9905
# Epoch 11/50
# 2969/2969 [==============================] - 39s 13ms/step - loss: 0.0248 - accuracy: 0.9898 - val_loss: 0.0229 - val_accuracy: 0.9910
# Epoch 12/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0230 - accuracy: 0.9907 - val_loss: 0.0218 - val_accuracy: 0.9913
# Epoch 13/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0212 - accuracy: 0.9916 - val_loss: 0.0201 - val_accuracy: 0.9921
# Epoch 14/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0195 - accuracy: 0.9924 - val_loss: 0.0188 - val_accuracy: 0.9930
# Epoch 15/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0182 - accuracy: 0.9929 - val_loss: 0.0198 - val_accuracy: 0.9930
# Epoch 16/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0171 - accuracy: 0.9934 - val_loss: 0.0182 - val_accuracy: 0.9931
# Epoch 17/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0160 - accuracy: 0.9939 - val_loss: 0.0176 - val_accuracy: 0.9933
# Epoch 18/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0151 - accuracy: 0.9942 - val_loss: 0.0179 - val_accuracy: 0.9935
# Epoch 19/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0142 - accuracy: 0.9946 - val_loss: 0.0167 - val_accuracy: 0.9938
# Epoch 20/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0133 - accuracy: 0.9951 - val_loss: 0.0184 - val_accuracy: 0.9933
# Epoch 21/50
# 2969/2969 [==============================] - 37s 13ms/step - loss: 0.0129 - accuracy: 0.9951 - val_loss: 0.0149 - val_accuracy: 0.9946
# Epoch 22/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0121 - accuracy: 0.9954 - val_loss: 0.0152 - val_accuracy: 0.9945
# Epoch 23/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0114 - accuracy: 0.9957 - val_loss: 0.0147 - val_accuracy: 0.9949
# Epoch 24/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0112 - accuracy: 0.9958 - val_loss: 0.0146 - val_accuracy: 0.9946
# Epoch 25/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.0147 - val_accuracy: 0.9949
# Epoch 26/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0098 - accuracy: 0.9964 - val_loss: 0.0175 - val_accuracy: 0.9945
# Epoch 27/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0098 - accuracy: 0.9964 - val_loss: 0.0141 - val_accuracy: 0.9952
# Epoch 28/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0093 - accuracy: 0.9965 - val_loss: 0.0133 - val_accuracy: 0.9953
# Epoch 29/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0089 - accuracy: 0.9967 - val_loss: 0.0150 - val_accuracy: 0.9950
# Epoch 30/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.0138 - val_accuracy: 0.9952
# Epoch 31/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.0134 - val_accuracy: 0.9953
# Epoch 32/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0080 - accuracy: 0.9971 - val_loss: 0.0148 - val_accuracy: 0.9951
# Epoch 33/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0126 - val_accuracy: 0.9958
# Epoch 34/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0074 - accuracy: 0.9973 - val_loss: 0.0146 - val_accuracy: 0.9953
# Epoch 35/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0137 - val_accuracy: 0.9956
# Epoch 36/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0140 - val_accuracy: 0.9956
# Epoch 37/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0138 - val_accuracy: 0.9956
# Epoch 38/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0066 - accuracy: 0.9976 - val_loss: 0.0137 - val_accuracy: 0.9956
# Epoch 39/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0067 - accuracy: 0.9976 - val_loss: 0.0134 - val_accuracy: 0.9958
# Epoch 40/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0151 - val_accuracy: 0.9952
# Epoch 41/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0139 - val_accuracy: 0.9956
# Epoch 42/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0140 - val_accuracy: 0.9957
# Epoch 43/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.0133 - val_accuracy: 0.9959
# Epoch 44/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0139 - val_accuracy: 0.9958
# Epoch 45/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.0131 - val_accuracy: 0.9958
# Epoch 46/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.0146 - val_accuracy: 0.9956
# Epoch 47/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.0138 - val_accuracy: 0.9959
# Epoch 48/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.0140 - val_accuracy: 0.9959
# Epoch 49/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0050 - accuracy: 0.9982 - val_loss: 0.0140 - val_accuracy: 0.9958
# Epoch 50/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0175 - val_accuracy: 0.9952
# 5938/5938 [==============================] - 25s 4ms/step
# Client 1 - Metrics after Local Epoch 1: [0.9951788458704394, 0.9916184185774304, 0.9987999747363102, 0.9951962409011768, 0.9997011073597775, 0.9915577170045685, 0.9903576917408787, 0.9903836650401739, array([[94196,   802],
#        [  114, 94884]])]
# Epoch 1/50
#    6/2969 [..............................] - ETA: 33s - loss: 0.6323 - accuracy: 0.7129
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0097s vs `on_train_batch_end` time: 0.0294s). Check your callbacks.
# 2969/2969 [==============================] - 43s 12ms/step - loss: 0.1016 - accuracy: 0.9578 - val_loss: 0.0525 - val_accuracy: 0.9778
# Epoch 2/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0532 - accuracy: 0.9774 - val_loss: 0.0491 - val_accuracy: 0.9787
# Epoch 3/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0489 - accuracy: 0.9790 - val_loss: 0.0475 - val_accuracy: 0.9801
# Epoch 4/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0453 - accuracy: 0.9802 - val_loss: 0.0432 - val_accuracy: 0.9808
# Epoch 5/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0419 - accuracy: 0.9816 - val_loss: 0.0399 - val_accuracy: 0.9824
# Epoch 6/50
# 2969/2969 [==============================] - 34s 11ms/step - loss: 0.0389 - accuracy: 0.9830 - val_loss: 0.0358 - val_accuracy: 0.9846
# Epoch 7/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0355 - accuracy: 0.9844 - val_loss: 0.0343 - val_accuracy: 0.9853
# Epoch 8/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0325 - accuracy: 0.9859 - val_loss: 0.0298 - val_accuracy: 0.9874
# Epoch 9/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0295 - accuracy: 0.9874 - val_loss: 0.0295 - val_accuracy: 0.9876
# Epoch 10/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0267 - accuracy: 0.9888 - val_loss: 0.0262 - val_accuracy: 0.9896
# Epoch 11/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0243 - accuracy: 0.9898 - val_loss: 0.0264 - val_accuracy: 0.9900
# Epoch 12/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0225 - accuracy: 0.9908 - val_loss: 0.0219 - val_accuracy: 0.9913
# Epoch 13/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0206 - accuracy: 0.9916 - val_loss: 0.0204 - val_accuracy: 0.9921
# Epoch 14/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0191 - accuracy: 0.9923 - val_loss: 0.0193 - val_accuracy: 0.9923
# Epoch 15/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0178 - accuracy: 0.9930 - val_loss: 0.0217 - val_accuracy: 0.9920
# Epoch 16/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0164 - accuracy: 0.9937 - val_loss: 0.0182 - val_accuracy: 0.9932
# Epoch 17/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0156 - accuracy: 0.9938 - val_loss: 0.0178 - val_accuracy: 0.9934
# Epoch 18/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0148 - accuracy: 0.9943 - val_loss: 0.0165 - val_accuracy: 0.9938
# Epoch 19/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0140 - accuracy: 0.9946 - val_loss: 0.0170 - val_accuracy: 0.9937
# Epoch 20/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0130 - accuracy: 0.9950 - val_loss: 0.0154 - val_accuracy: 0.9944
# Epoch 21/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0124 - accuracy: 0.9953 - val_loss: 0.0153 - val_accuracy: 0.9944
# Epoch 22/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0120 - accuracy: 0.9954 - val_loss: 0.0145 - val_accuracy: 0.9949
# Epoch 23/50
# 2969/2969 [==============================] - 40s 13ms/step - loss: 0.0112 - accuracy: 0.9958 - val_loss: 0.0160 - val_accuracy: 0.9943
# Epoch 24/50
# 2969/2969 [==============================] - 39s 13ms/step - loss: 0.0108 - accuracy: 0.9960 - val_loss: 0.0151 - val_accuracy: 0.9947
# Epoch 25/50
# 2969/2969 [==============================] - 39s 13ms/step - loss: 0.0103 - accuracy: 0.9961 - val_loss: 0.0148 - val_accuracy: 0.9952
# Epoch 26/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0101 - accuracy: 0.9963 - val_loss: 0.0140 - val_accuracy: 0.9953
# Epoch 27/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.0132 - val_accuracy: 0.9955
# Epoch 28/50
# 2969/2969 [==============================] - 40s 14ms/step - loss: 0.0090 - accuracy: 0.9966 - val_loss: 0.0141 - val_accuracy: 0.9952
# Epoch 29/50
# 2969/2969 [==============================] - 40s 13ms/step - loss: 0.0088 - accuracy: 0.9967 - val_loss: 0.0132 - val_accuracy: 0.9955
# Epoch 30/50
# 2969/2969 [==============================] - 40s 14ms/step - loss: 0.0086 - accuracy: 0.9968 - val_loss: 0.0134 - val_accuracy: 0.9957
# Epoch 31/50
# 2969/2969 [==============================] - 40s 13ms/step - loss: 0.0080 - accuracy: 0.9970 - val_loss: 0.0134 - val_accuracy: 0.9956
# Epoch 32/50
# 2969/2969 [==============================] - 40s 13ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.0144 - val_accuracy: 0.9951
# Epoch 33/50
# 2969/2969 [==============================] - 37s 13ms/step - loss: 0.0075 - accuracy: 0.9972 - val_loss: 0.0141 - val_accuracy: 0.9956
# Epoch 34/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0150 - val_accuracy: 0.9952
# Epoch 35/50
# 2969/2969 [==============================] - 41s 14ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0151 - val_accuracy: 0.9951
# Epoch 36/50
# 2969/2969 [==============================] - 41s 14ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0127 - val_accuracy: 0.9961
# Epoch 37/50
# 2969/2969 [==============================] - 37s 13ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0135 - val_accuracy: 0.9958
# Epoch 38/50
# 2969/2969 [==============================] - 39s 13ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.0124 - val_accuracy: 0.9960
# Epoch 39/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.0167 - val_accuracy: 0.9950
# Epoch 40/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0138 - val_accuracy: 0.9960
# Epoch 41/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0130 - val_accuracy: 0.9962
# Epoch 42/50
# 2969/2969 [==============================] - 39s 13ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0128 - val_accuracy: 0.9961
# Epoch 43/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0056 - accuracy: 0.9980 - val_loss: 0.0138 - val_accuracy: 0.9958
# Epoch 44/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0135 - val_accuracy: 0.9960
# Epoch 45/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.0135 - val_accuracy: 0.9961
# Epoch 46/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0156 - val_accuracy: 0.9960
# Epoch 47/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.0141 - val_accuracy: 0.9961
# Epoch 48/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 0.0132 - val_accuracy: 0.9961
# Epoch 49/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 0.0129 - val_accuracy: 0.9962
# Epoch 50/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 0.0138 - val_accuracy: 0.9962
# 5938/5938 [==============================] - 25s 4ms/step
# Client 2 - Metrics after Local Epoch 1: [0.9961841301922145, 0.9941917153311456, 0.9981999621044654, 0.9961918068694551, 0.9997559325490687, 0.9941682982799638, 0.9923682603844292, 0.9923763256150043, array([[94444,   554],
#        [  171, 94827]])]
# Epoch 1/50
#    6/2969 [..............................] - ETA: 34s - loss: 0.6289 - accuracy: 0.7324
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0102s vs `on_train_batch_end` time: 0.0294s). Check your callbacks.
# 2969/2969 [==============================] - 45s 13ms/step - loss: 0.1065 - accuracy: 0.9563 - val_loss: 0.0526 - val_accuracy: 0.9778
# Epoch 2/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0544 - accuracy: 0.9777 - val_loss: 0.0479 - val_accuracy: 0.9792
# Epoch 3/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0490 - accuracy: 0.9794 - val_loss: 0.0445 - val_accuracy: 0.9806
# Epoch 4/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0451 - accuracy: 0.9808 - val_loss: 0.0441 - val_accuracy: 0.9810
# Epoch 5/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0411 - accuracy: 0.9821 - val_loss: 0.0371 - val_accuracy: 0.9836
# Epoch 6/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0378 - accuracy: 0.9835 - val_loss: 0.0370 - val_accuracy: 0.9838
# Epoch 7/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0347 - accuracy: 0.9849 - val_loss: 0.0347 - val_accuracy: 0.9850
# Epoch 8/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0315 - accuracy: 0.9863 - val_loss: 0.0292 - val_accuracy: 0.9875
# Epoch 9/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0288 - accuracy: 0.9876 - val_loss: 0.0259 - val_accuracy: 0.9888
# Epoch 10/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0262 - accuracy: 0.9890 - val_loss: 0.0251 - val_accuracy: 0.9896
# Epoch 11/50
# 2969/2969 [==============================] - 34s 11ms/step - loss: 0.0238 - accuracy: 0.9902 - val_loss: 0.0244 - val_accuracy: 0.9907
# Epoch 12/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0221 - accuracy: 0.9910 - val_loss: 0.0235 - val_accuracy: 0.9907
# Epoch 13/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0204 - accuracy: 0.9918 - val_loss: 0.0198 - val_accuracy: 0.9922
# Epoch 14/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0187 - accuracy: 0.9925 - val_loss: 0.0210 - val_accuracy: 0.9920
# Epoch 15/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0173 - accuracy: 0.9932 - val_loss: 0.0192 - val_accuracy: 0.9927
# Epoch 16/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0161 - accuracy: 0.9937 - val_loss: 0.0174 - val_accuracy: 0.9936
# Epoch 17/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0151 - accuracy: 0.9942 - val_loss: 0.0201 - val_accuracy: 0.9927
# Epoch 18/50
# 2969/2969 [==============================] - 34s 11ms/step - loss: 0.0141 - accuracy: 0.9946 - val_loss: 0.0169 - val_accuracy: 0.9939
# Epoch 19/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0135 - accuracy: 0.9949 - val_loss: 0.0150 - val_accuracy: 0.9945
# Epoch 20/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0127 - accuracy: 0.9952 - val_loss: 0.0151 - val_accuracy: 0.9947
# Epoch 21/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0119 - accuracy: 0.9955 - val_loss: 0.0145 - val_accuracy: 0.9948
# Epoch 22/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0114 - accuracy: 0.9957 - val_loss: 0.0155 - val_accuracy: 0.9945
# Epoch 23/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0107 - accuracy: 0.9959 - val_loss: 0.0142 - val_accuracy: 0.9950
# Epoch 24/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0105 - accuracy: 0.9961 - val_loss: 0.0142 - val_accuracy: 0.9949
# Epoch 25/50
# 2969/2969 [==============================] - 37s 13ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.0147 - val_accuracy: 0.9951
# Epoch 26/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0095 - accuracy: 0.9965 - val_loss: 0.0143 - val_accuracy: 0.9952
# Epoch 27/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0089 - accuracy: 0.9967 - val_loss: 0.0158 - val_accuracy: 0.9948
# Epoch 28/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0086 - accuracy: 0.9968 - val_loss: 0.0152 - val_accuracy: 0.9949
# Epoch 29/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0082 - accuracy: 0.9970 - val_loss: 0.0159 - val_accuracy: 0.9947
# Epoch 30/50
# 2969/2969 [==============================] - 39s 13ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0133 - val_accuracy: 0.9958
# Epoch 31/50
# 2969/2969 [==============================] - 39s 13ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.0140 - val_accuracy: 0.9954
# Epoch 32/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.0149 - val_accuracy: 0.9951
# Epoch 33/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.0127 - val_accuracy: 0.9958
# Epoch 34/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0140 - val_accuracy: 0.9956
# Epoch 35/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0136 - val_accuracy: 0.9958
# Epoch 36/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0134 - val_accuracy: 0.9958
# Epoch 37/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.0145 - val_accuracy: 0.9955
# Epoch 38/50
# 2969/2969 [==============================] - 38s 13ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0188 - val_accuracy: 0.9945
# Epoch 39/50
# 2969/2969 [==============================] - 34s 12ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0152 - val_accuracy: 0.9954
# Epoch 40/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0138 - val_accuracy: 0.9957
# Epoch 41/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0059 - accuracy: 0.9979 - val_loss: 0.0153 - val_accuracy: 0.9953
# Epoch 42/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0056 - accuracy: 0.9980 - val_loss: 0.0140 - val_accuracy: 0.9958
# Epoch 43/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.0129 - val_accuracy: 0.9961
# Epoch 44/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.0135 - val_accuracy: 0.9960
# Epoch 45/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.0149 - val_accuracy: 0.9959
# Epoch 46/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.0131 - val_accuracy: 0.9961
# Epoch 47/50
# 2969/2969 [==============================] - 35s 12ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.0141 - val_accuracy: 0.9958
# Epoch 48/50
# 2969/2969 [==============================] - 36s 12ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.0153 - val_accuracy: 0.9957
# Epoch 49/50
# 2969/2969 [==============================] - 37s 12ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0138 - val_accuracy: 0.9959
# Epoch 50/50
# 2969/2969 [==============================] - 37s 13ms/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.0139 - val_accuracy: 0.9961
# 5938/5938 [==============================] - 25s 4ms/step
# Client 3 - Metrics after Local Epoch 1: [0.9960946546243079, 0.9940249067046837, 0.9981894355670645, 0.9961028183661249, 0.9997146229981032, 0.9939998736815512, 0.9921893092486158, 0.9921980170293475, array([[94428,   570],
#        [  172, 94826]])]
