# %%
# prompt: mount

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GroupShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, cohen_kappa_score, matthews_corrcoef
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, BatchNormalization, LeakyReLU, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
from tensorflow.keras.backend import clear_session
import datetime
import csv
from tensorflow.keras.layers import Conv1D, BatchNormalization, LeakyReLU, MaxPool1D, Dropout, GlobalAveragePooling1D, Dense

# %%
# Check if GPU is available
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Enable mixed precision
tf.keras.mixed_precision.set_global_policy('mixed_float16')
# Out:
# Num GPUs Available:  1

# %%
# Load data
df = pd.read_csv("/content/drive/MyDrive/DHS/Diabetes/Data/India/Data Balance/oversample_smote.csv")

selected_columns = ['hv005', 'hv021', 'hv023', 'hv105', 'hv115', 'hv104', 'hv106', 'hml18',
                    'shb70', 'ha53', 'shb13', 'hv206', 'hv116', 'avg_sys', 'avg_dia', 'bmi']

# Split the data into features and target
X = df[selected_columns]
y = df['final_diabetes']

# Convert X and y to numpy arrays if they are not already
X = np.array(X)
y = np.array(y)

# Standardize the data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Reshape data for the CNN model
X = X.reshape((X.shape[0], X.shape[1], 1))

# %%
# Define the CNN model architecture using a function
def cnnmodel():
    clear_session()
    model = Sequential()
    model.add(Conv1D(filters=128, kernel_size=3, strides=1, padding='same', input_shape=(16, 1)))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPool1D(pool_size=2, strides=2))
    model.add(Dropout(0.3))

    model.add(Conv1D(filters=64, kernel_size=3, strides=1, padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(MaxPool1D(pool_size=2, strides=2))
    model.add(Dropout(0.3))

    model.add(Conv1D(filters=32, kernel_size=3, strides=1, padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(GlobalAveragePooling1D())

    model.add(Dense(1, activation='sigmoid', dtype='float32'))  # Ensure output layer is float32

    optimizer = Adam(learning_rate=0.001)  # Static learning rate of 0.001
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Evaluate the model
def evaluate_model(model, X_val, y_val):
    y_val_pred = model.predict(X_val)
    y_val_pred_binary = (y_val_pred > 0.5).astype(int)

    accuracy = accuracy_score(y_val, y_val_pred_binary)
    precision = precision_score(y_val, y_val_pred_binary)
    recall = recall_score(y_val, y_val_pred_binary)
    f1 = f1_score(y_val, y_val_pred_binary)
    roc_auc = roc_auc_score(y_val, y_val_pred)
    cm = confusion_matrix(y_val, y_val_pred_binary)
    specificity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
    kappa = cohen_kappa_score(y_val, y_val_pred_binary)
    mcc = matthews_corrcoef(y_val, y_val_pred_binary)

    metrics = [accuracy, precision, recall, f1, roc_auc, specificity, kappa, mcc, cm]
    return metrics

# %%
from sklearn.model_selection import StratifiedKFold

class FederatedData:
    def __init__(self, X, y, num_clients, test_size=0.2):
        self.X = X
        self.y = y
        self.num_clients = num_clients
        self.test_size = test_size
        self.partitions = []
        self.create_partitions()

    def create_partitions(self):
        skf = StratifiedKFold(n_splits=self.num_clients, shuffle=True, random_state=42)
        for train_index, test_index in skf.split(self.X, self.y):
            X_train, X_test = self.X[train_index], self.X[test_index]
            y_train, y_test = self.y[train_index], self.y[test_index]
            self.partitions.append((X_train, y_train, X_test, y_test))
            print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}")

    def get_training_and_validation_data(self, client_idx):
        if client_idx < 0 or client_idx >= len(self.partitions):
            raise ValueError(f"Invalid client index. Must be between 0 and {len(self.partitions) - 1}.")
        partition_X_train, partition_y_train, partition_X_test, partition_y_test = self.partitions[client_idx]
        X_train, X_val, y_train, y_val = train_test_split(partition_X_train, partition_y_train, test_size=0.2, stratify=partition_y_train, random_state=42)
        return X_train, X_val, y_train, y_val, partition_X_test, partition_y_test

# Initialize federated data
federated_data = FederatedData(X, y, num_clients=3)
# Out:
# Train shape: (949976, 16, 1), Test shape: (474988, 16, 1)
# Train shape: (949976, 16, 1), Test shape: (474988, 16, 1)
# Train shape: (949976, 16, 1), Test shape: (474988, 16, 1)

# %%
import os
import datetime
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import csv

# Custom CSV Logger
class CustomCSVLogger(tf.keras.callbacks.Callback):
    def __init__(self, filename, separator=',', append=False):
        self.sep = separator
        self.filename = filename
        self.append = append
        self.file = None
        self.writer = None
        self.keys = None
        super(CustomCSVLogger, self).__init__()

    def on_train_begin(self, logs=None):
        if not self.append and os.path.isfile(self.filename):
            os.remove(self.filename)
        mode = 'a' if self.append else 'w'
        self.file = open(self.filename, mode, newline='')
        self.writer = csv.writer(self.file, delimiter=self.sep)

    def on_epoch_end(self, epoch, logs=None):
        if self.keys is None:
            self.keys = sorted(logs.keys())
            self.writer.writerow(self.keys)
        row = [logs.get(key) for key in self.keys]
        self.writer.writerow(row)

    def on_train_end(self, logs=None):
        self.file.close()


# Initialize global model
input_shape = X.shape[1:]
global_model = cnnmodel()
num_clients = 3
local_epochs = 1

# CSV file to store performance metrics
csv_filename = "/content/drive/MyDrive/DHS/Diabetes/Data/India/Deep Learning/CNN Federated/16 Features/CNN_16_features_federated_learning_metrics.csv"
header = ['Local Epoch', 'Client', 'Accuracy', 'Precision', 'Recall', 'F1-Score', 'ROC AUC', 'Specificity', 'Kappa', 'MCC', 'Confusion Matrix']
with open(csv_filename, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)

# Federated training process
for local_epoch in range(1, local_epochs + 1):
    print(f"Local Epoch {local_epoch}:")
    client_models = []

    # Create a directory for the current local epoch
    epoch_dir = f"/content/drive/MyDrive/DHS/Diabetes/Data/India/Deep Learning/CNN Federated/16 Features/epoch_{local_epoch}"
    os.makedirs(epoch_dir, exist_ok=True)

    for client in range(num_clients):
        X_train, X_val, y_train, y_val, X_test, y_test = federated_data.get_training_and_validation_data(client)
        client_model = cnnmodel()
        client_model.set_weights(global_model.get_weights())  # Initialize with global weights

        with tf.device('/GPU:0'):
            log_dir = os.path.join(epoch_dir, "logs/profile/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
            tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, profile_batch=0)
            csv_logger = CustomCSVLogger(os.path.join(epoch_dir, f"training_client_{client+1}_epoch_{local_epoch}.csv"))

            history = client_model.fit(
                X_train, y_train,
                epochs=50,  # Train for 10 epochs (as a placeholder, adjust as needed)
                batch_size=256,
                validation_data=(X_val, y_val),
                verbose=1,
                callbacks=[tensorboard_callback, csv_logger]
            )

        # Evaluate the client model
        client_metrics = evaluate_model(client_model, X_val, y_val)
        print(f"Client {client + 1} - Metrics after Local Epoch {local_epoch}: {client_metrics}")

        # Save client model performance to CSV
        with open(csv_filename, 'a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([local_epoch, client + 1] + client_metrics[:-1] + [np.array2string(client_metrics[-1], separator=',')])

        client_models.append(client_model)

    # Aggregating weights from client models to update global model
    global_weights = global_model.get_weights()
    new_weights = [client_model.get_weights() for client_model in client_models]

    averaged_weights = [np.mean(np.array([client_weight[layer] for client_weight in new_weights]), axis=0) for layer in range(len(global_weights))]
    global_model.set_weights(averaged_weights)

# Save the global model
global_model.save("/content/drive/MyDrive/DHS/Diabetes/Data/India/Deep Learning/CNN Federated/16 Features/CNN_16_features_global_model.keras")
# Out:
# Local Epoch 1:
# Epoch 1/50
#    1/2969 [..............................] - ETA: 6:54:12 - loss: 0.7592 - accuracy: 0.4492
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0062s vs `on_train_batch_end` time: 0.0100s). Check your callbacks.
# 2969/2969 [==============================] - 36s 9ms/step - loss: 0.1058 - accuracy: 0.9615 - val_loss: 0.0688 - val_accuracy: 0.9756
# Epoch 2/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0697 - accuracy: 0.9743 - val_loss: 0.0543 - val_accuracy: 0.9786
# Epoch 3/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0649 - accuracy: 0.9756 - val_loss: 0.0544 - val_accuracy: 0.9784
# Epoch 4/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0622 - accuracy: 0.9762 - val_loss: 0.0490 - val_accuracy: 0.9799
# Epoch 5/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0605 - accuracy: 0.9767 - val_loss: 0.0507 - val_accuracy: 0.9794
# Epoch 6/50
# 2969/2969 [==============================] - 28s 10ms/step - loss: 0.0594 - accuracy: 0.9771 - val_loss: 0.0472 - val_accuracy: 0.9804
# Epoch 7/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0581 - accuracy: 0.9773 - val_loss: 0.0486 - val_accuracy: 0.9795
# Epoch 8/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0572 - accuracy: 0.9776 - val_loss: 0.0451 - val_accuracy: 0.9811
# Epoch 9/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0566 - accuracy: 0.9776 - val_loss: 0.0454 - val_accuracy: 0.9810
# Epoch 10/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0560 - accuracy: 0.9777 - val_loss: 0.0454 - val_accuracy: 0.9811
# Epoch 11/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0554 - accuracy: 0.9779 - val_loss: 0.0475 - val_accuracy: 0.9803
# Epoch 12/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0551 - accuracy: 0.9782 - val_loss: 0.0445 - val_accuracy: 0.9814
# Epoch 13/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0548 - accuracy: 0.9782 - val_loss: 0.0441 - val_accuracy: 0.9815
# Epoch 14/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0544 - accuracy: 0.9783 - val_loss: 0.0439 - val_accuracy: 0.9815
# Epoch 15/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0539 - accuracy: 0.9784 - val_loss: 0.0440 - val_accuracy: 0.9813
# Epoch 16/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0538 - accuracy: 0.9784 - val_loss: 0.0433 - val_accuracy: 0.9816
# Epoch 17/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0537 - accuracy: 0.9784 - val_loss: 0.0435 - val_accuracy: 0.9814
# Epoch 18/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0531 - accuracy: 0.9788 - val_loss: 0.0433 - val_accuracy: 0.9817
# Epoch 19/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0527 - accuracy: 0.9788 - val_loss: 0.0434 - val_accuracy: 0.9816
# Epoch 20/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0524 - accuracy: 0.9790 - val_loss: 0.0426 - val_accuracy: 0.9820
# Epoch 21/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0524 - accuracy: 0.9789 - val_loss: 0.0433 - val_accuracy: 0.9818
# Epoch 22/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0522 - accuracy: 0.9790 - val_loss: 0.0423 - val_accuracy: 0.9820
# Epoch 23/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0522 - accuracy: 0.9790 - val_loss: 0.0416 - val_accuracy: 0.9822
# Epoch 24/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0520 - accuracy: 0.9791 - val_loss: 0.0426 - val_accuracy: 0.9820
# Epoch 25/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0516 - accuracy: 0.9792 - val_loss: 0.0422 - val_accuracy: 0.9818
# Epoch 26/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0519 - accuracy: 0.9790 - val_loss: 0.0424 - val_accuracy: 0.9820
# Epoch 27/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0515 - accuracy: 0.9792 - val_loss: 0.0411 - val_accuracy: 0.9826
# Epoch 28/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0512 - accuracy: 0.9794 - val_loss: 0.0410 - val_accuracy: 0.9827
# Epoch 29/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0512 - accuracy: 0.9791 - val_loss: 0.0419 - val_accuracy: 0.9823
# Epoch 30/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0514 - accuracy: 0.9793 - val_loss: 0.0411 - val_accuracy: 0.9824
# Epoch 31/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0511 - accuracy: 0.9792 - val_loss: 0.0404 - val_accuracy: 0.9827
# Epoch 32/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0508 - accuracy: 0.9795 - val_loss: 0.0410 - val_accuracy: 0.9826
# Epoch 33/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0507 - accuracy: 0.9794 - val_loss: 0.0412 - val_accuracy: 0.9826
# Epoch 34/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0506 - accuracy: 0.9794 - val_loss: 0.0406 - val_accuracy: 0.9828
# Epoch 35/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0507 - accuracy: 0.9795 - val_loss: 0.0418 - val_accuracy: 0.9822
# Epoch 36/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0505 - accuracy: 0.9795 - val_loss: 0.0406 - val_accuracy: 0.9828
# Epoch 37/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0504 - accuracy: 0.9796 - val_loss: 0.0404 - val_accuracy: 0.9827
# Epoch 38/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0500 - accuracy: 0.9797 - val_loss: 0.0414 - val_accuracy: 0.9827
# Epoch 39/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0502 - accuracy: 0.9797 - val_loss: 0.0403 - val_accuracy: 0.9826
# Epoch 40/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0499 - accuracy: 0.9798 - val_loss: 0.0401 - val_accuracy: 0.9829
# Epoch 41/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0501 - accuracy: 0.9799 - val_loss: 0.0405 - val_accuracy: 0.9826
# Epoch 42/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0498 - accuracy: 0.9798 - val_loss: 0.0399 - val_accuracy: 0.9828
# Epoch 43/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0498 - accuracy: 0.9797 - val_loss: 0.0398 - val_accuracy: 0.9829
# Epoch 44/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0496 - accuracy: 0.9800 - val_loss: 0.0398 - val_accuracy: 0.9831
# Epoch 45/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0496 - accuracy: 0.9799 - val_loss: 0.0399 - val_accuracy: 0.9830
# Epoch 46/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0498 - accuracy: 0.9796 - val_loss: 0.0399 - val_accuracy: 0.9829
# Epoch 47/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0496 - accuracy: 0.9798 - val_loss: 0.0391 - val_accuracy: 0.9834
# Epoch 48/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0495 - accuracy: 0.9800 - val_loss: 0.0395 - val_accuracy: 0.9829
# Epoch 49/50
# 2969/2969 [==============================] - 26s 9ms/step - loss: 0.0493 - accuracy: 0.9798 - val_loss: 0.0393 - val_accuracy: 0.9833
# Epoch 50/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0494 - accuracy: 0.9800 - val_loss: 0.0403 - val_accuracy: 0.9827
# 5938/5938 [==============================] - 13s 2ms/step
# Client 1 - Metrics after Local Epoch 1: [0.9827101623192067, 0.9887137513188605, 0.9765679277458473, 0.9826033077546352, 0.9990293900467702, 0.9888523968925662, 0.9654203246384134, 0.9654931777972536, array([[93939,  1059],
#        [ 2226, 92772]])]
# Epoch 1/50
#    1/2969 [..............................] - ETA: 2:14:08 - loss: 0.7029 - accuracy: 0.5430
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0070s vs `on_train_batch_end` time: 0.0094s). Check your callbacks.
# 2969/2969 [==============================] - 30s 9ms/step - loss: 0.1035 - accuracy: 0.9623 - val_loss: 0.0587 - val_accuracy: 0.9775
# Epoch 2/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0696 - accuracy: 0.9744 - val_loss: 0.0581 - val_accuracy: 0.9777
# Epoch 3/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0648 - accuracy: 0.9755 - val_loss: 0.0535 - val_accuracy: 0.9784
# Epoch 4/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0625 - accuracy: 0.9762 - val_loss: 0.0516 - val_accuracy: 0.9790
# Epoch 5/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0606 - accuracy: 0.9765 - val_loss: 0.0500 - val_accuracy: 0.9793
# Epoch 6/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0592 - accuracy: 0.9770 - val_loss: 0.0495 - val_accuracy: 0.9796
# Epoch 7/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0580 - accuracy: 0.9774 - val_loss: 0.0487 - val_accuracy: 0.9799
# Epoch 8/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0573 - accuracy: 0.9775 - val_loss: 0.0485 - val_accuracy: 0.9795
# Epoch 9/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0568 - accuracy: 0.9775 - val_loss: 0.0475 - val_accuracy: 0.9799
# Epoch 10/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0565 - accuracy: 0.9777 - val_loss: 0.0491 - val_accuracy: 0.9798
# Epoch 11/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0559 - accuracy: 0.9778 - val_loss: 0.0467 - val_accuracy: 0.9805
# Epoch 12/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0552 - accuracy: 0.9782 - val_loss: 0.0474 - val_accuracy: 0.9800
# Epoch 13/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0547 - accuracy: 0.9783 - val_loss: 0.0453 - val_accuracy: 0.9809
# Epoch 14/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0545 - accuracy: 0.9783 - val_loss: 0.0464 - val_accuracy: 0.9805
# Epoch 15/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0541 - accuracy: 0.9785 - val_loss: 0.0460 - val_accuracy: 0.9805
# Epoch 16/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0537 - accuracy: 0.9785 - val_loss: 0.0457 - val_accuracy: 0.9808
# Epoch 17/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0537 - accuracy: 0.9786 - val_loss: 0.0451 - val_accuracy: 0.9811
# Epoch 18/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0534 - accuracy: 0.9785 - val_loss: 0.0442 - val_accuracy: 0.9810
# Epoch 19/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0532 - accuracy: 0.9786 - val_loss: 0.0455 - val_accuracy: 0.9809
# Epoch 20/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0529 - accuracy: 0.9788 - val_loss: 0.0442 - val_accuracy: 0.9810
# Epoch 21/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0527 - accuracy: 0.9789 - val_loss: 0.0439 - val_accuracy: 0.9812
# Epoch 22/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0524 - accuracy: 0.9789 - val_loss: 0.0445 - val_accuracy: 0.9811
# Epoch 23/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0523 - accuracy: 0.9789 - val_loss: 0.0432 - val_accuracy: 0.9814
# Epoch 24/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0521 - accuracy: 0.9790 - val_loss: 0.0444 - val_accuracy: 0.9810
# Epoch 25/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0520 - accuracy: 0.9791 - val_loss: 0.0459 - val_accuracy: 0.9803
# Epoch 26/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0519 - accuracy: 0.9790 - val_loss: 0.0430 - val_accuracy: 0.9818
# Epoch 27/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0519 - accuracy: 0.9790 - val_loss: 0.0432 - val_accuracy: 0.9815
# Epoch 28/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0518 - accuracy: 0.9791 - val_loss: 0.0444 - val_accuracy: 0.9809
# Epoch 29/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0517 - accuracy: 0.9791 - val_loss: 0.0438 - val_accuracy: 0.9810
# Epoch 30/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0513 - accuracy: 0.9792 - val_loss: 0.0426 - val_accuracy: 0.9816
# Epoch 31/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0513 - accuracy: 0.9792 - val_loss: 0.0429 - val_accuracy: 0.9816
# Epoch 32/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0511 - accuracy: 0.9795 - val_loss: 0.0422 - val_accuracy: 0.9818
# Epoch 33/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0507 - accuracy: 0.9793 - val_loss: 0.0420 - val_accuracy: 0.9819
# Epoch 34/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0511 - accuracy: 0.9794 - val_loss: 0.0424 - val_accuracy: 0.9818
# Epoch 35/50
# 2969/2969 [==============================] - 28s 10ms/step - loss: 0.0505 - accuracy: 0.9793 - val_loss: 0.0421 - val_accuracy: 0.9821
# Epoch 36/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0507 - accuracy: 0.9795 - val_loss: 0.0433 - val_accuracy: 0.9814
# Epoch 37/50
# 2969/2969 [==============================] - 28s 10ms/step - loss: 0.0507 - accuracy: 0.9794 - val_loss: 0.0425 - val_accuracy: 0.9819
# Epoch 38/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0504 - accuracy: 0.9796 - val_loss: 0.0434 - val_accuracy: 0.9816
# Epoch 39/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0505 - accuracy: 0.9795 - val_loss: 0.0416 - val_accuracy: 0.9821
# Epoch 40/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0501 - accuracy: 0.9796 - val_loss: 0.0415 - val_accuracy: 0.9822
# Epoch 41/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0502 - accuracy: 0.9795 - val_loss: 0.0420 - val_accuracy: 0.9820
# Epoch 42/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0499 - accuracy: 0.9797 - val_loss: 0.0427 - val_accuracy: 0.9816
# Epoch 43/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0501 - accuracy: 0.9796 - val_loss: 0.0414 - val_accuracy: 0.9822
# Epoch 44/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0498 - accuracy: 0.9798 - val_loss: 0.0426 - val_accuracy: 0.9818
# Epoch 45/50
# 2969/2969 [==============================] - 27s 9ms/step - loss: 0.0498 - accuracy: 0.9800 - val_loss: 0.0421 - val_accuracy: 0.9820
# Epoch 46/50
# 2969/2969 [==============================] - 28s 10ms/step - loss: 0.0498 - accuracy: 0.9799 - val_loss: 0.0415 - val_accuracy: 0.9821
# Epoch 47/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0497 - accuracy: 0.9798 - val_loss: 0.0407 - val_accuracy: 0.9824
# Epoch 48/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0497 - accuracy: 0.9799 - val_loss: 0.0414 - val_accuracy: 0.9821
# Epoch 49/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0496 - accuracy: 0.9797 - val_loss: 0.0412 - val_accuracy: 0.9823
# Epoch 50/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0497 - accuracy: 0.9797 - val_loss: 0.0412 - val_accuracy: 0.9824
# 5938/5938 [==============================] - 13s 2ms/step
# Client 2 - Metrics after Local Epoch 1: [0.982378576391082, 0.988279168886521, 0.9763363439230299, 0.9822714564093873, 0.9989802351239253, 0.9884208088591339, 0.9647571527821638, 0.9648276043127736, array([[93898,  1100],
#        [ 2248, 92750]])]
# Epoch 1/50
#    1/2969 [..............................] - ETA: 2:27:28 - loss: 0.7646 - accuracy: 0.4297
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0080s vs `on_train_batch_end` time: 0.0098s). Check your callbacks.
# 2969/2969 [==============================] - 31s 9ms/step - loss: 0.1044 - accuracy: 0.9621 - val_loss: 0.0574 - val_accuracy: 0.9777
# Epoch 2/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0699 - accuracy: 0.9745 - val_loss: 0.0533 - val_accuracy: 0.9785
# Epoch 3/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0650 - accuracy: 0.9757 - val_loss: 0.0523 - val_accuracy: 0.9785
# Epoch 4/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0624 - accuracy: 0.9762 - val_loss: 0.0534 - val_accuracy: 0.9784
# Epoch 5/50
# 2969/2969 [==============================] - 28s 10ms/step - loss: 0.0605 - accuracy: 0.9768 - val_loss: 0.0490 - val_accuracy: 0.9793
# Epoch 6/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0591 - accuracy: 0.9771 - val_loss: 0.0497 - val_accuracy: 0.9791
# Epoch 7/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0582 - accuracy: 0.9773 - val_loss: 0.0475 - val_accuracy: 0.9799
# Epoch 8/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0572 - accuracy: 0.9774 - val_loss: 0.0482 - val_accuracy: 0.9797
# Epoch 9/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0566 - accuracy: 0.9778 - val_loss: 0.0488 - val_accuracy: 0.9799
# Epoch 10/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0562 - accuracy: 0.9779 - val_loss: 0.0462 - val_accuracy: 0.9802
# Epoch 11/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0555 - accuracy: 0.9781 - val_loss: 0.0452 - val_accuracy: 0.9806
# Epoch 12/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0550 - accuracy: 0.9784 - val_loss: 0.0464 - val_accuracy: 0.9803
# Epoch 13/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0547 - accuracy: 0.9783 - val_loss: 0.0468 - val_accuracy: 0.9805
# Epoch 14/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0546 - accuracy: 0.9783 - val_loss: 0.0443 - val_accuracy: 0.9810
# Epoch 15/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0542 - accuracy: 0.9784 - val_loss: 0.0446 - val_accuracy: 0.9809
# Epoch 16/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0539 - accuracy: 0.9785 - val_loss: 0.0454 - val_accuracy: 0.9805
# Epoch 17/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0534 - accuracy: 0.9787 - val_loss: 0.0460 - val_accuracy: 0.9805
# Epoch 18/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0535 - accuracy: 0.9787 - val_loss: 0.0448 - val_accuracy: 0.9807
# Epoch 19/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0529 - accuracy: 0.9788 - val_loss: 0.0437 - val_accuracy: 0.9813
# Epoch 20/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0530 - accuracy: 0.9789 - val_loss: 0.0441 - val_accuracy: 0.9812
# Epoch 21/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0526 - accuracy: 0.9791 - val_loss: 0.0442 - val_accuracy: 0.9810
# Epoch 22/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0529 - accuracy: 0.9789 - val_loss: 0.0434 - val_accuracy: 0.9814
# Epoch 23/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0524 - accuracy: 0.9789 - val_loss: 0.0433 - val_accuracy: 0.9814
# Epoch 24/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0522 - accuracy: 0.9790 - val_loss: 0.0444 - val_accuracy: 0.9811
# Epoch 25/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0522 - accuracy: 0.9791 - val_loss: 0.0427 - val_accuracy: 0.9815
# Epoch 26/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0517 - accuracy: 0.9792 - val_loss: 0.0424 - val_accuracy: 0.9816
# Epoch 27/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0518 - accuracy: 0.9792 - val_loss: 0.0426 - val_accuracy: 0.9817
# Epoch 28/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0516 - accuracy: 0.9791 - val_loss: 0.0428 - val_accuracy: 0.9818
# Epoch 29/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0515 - accuracy: 0.9792 - val_loss: 0.0434 - val_accuracy: 0.9817
# Epoch 30/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0514 - accuracy: 0.9793 - val_loss: 0.0419 - val_accuracy: 0.9819
# Epoch 31/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0512 - accuracy: 0.9794 - val_loss: 0.0424 - val_accuracy: 0.9819
# Epoch 32/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0512 - accuracy: 0.9797 - val_loss: 0.0413 - val_accuracy: 0.9820
# Epoch 33/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0511 - accuracy: 0.9795 - val_loss: 0.0422 - val_accuracy: 0.9818
# Epoch 34/50
# 2969/2969 [==============================] - 28s 10ms/step - loss: 0.0511 - accuracy: 0.9794 - val_loss: 0.0422 - val_accuracy: 0.9820
# Epoch 35/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0509 - accuracy: 0.9796 - val_loss: 0.0416 - val_accuracy: 0.9820
# Epoch 36/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0507 - accuracy: 0.9795 - val_loss: 0.0410 - val_accuracy: 0.9823
# Epoch 37/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0507 - accuracy: 0.9796 - val_loss: 0.0409 - val_accuracy: 0.9824
# Epoch 38/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0506 - accuracy: 0.9795 - val_loss: 0.0423 - val_accuracy: 0.9820
# Epoch 39/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0505 - accuracy: 0.9796 - val_loss: 0.0433 - val_accuracy: 0.9814
# Epoch 40/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0506 - accuracy: 0.9796 - val_loss: 0.0412 - val_accuracy: 0.9824
# Epoch 41/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0503 - accuracy: 0.9797 - val_loss: 0.0408 - val_accuracy: 0.9823
# Epoch 42/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0502 - accuracy: 0.9796 - val_loss: 0.0411 - val_accuracy: 0.9822
# Epoch 43/50
# 2969/2969 [==============================] - 28s 10ms/step - loss: 0.0503 - accuracy: 0.9796 - val_loss: 0.0421 - val_accuracy: 0.9818
# Epoch 44/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0500 - accuracy: 0.9797 - val_loss: 0.0410 - val_accuracy: 0.9823
# Epoch 45/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0501 - accuracy: 0.9797 - val_loss: 0.0414 - val_accuracy: 0.9823
# Epoch 46/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0500 - accuracy: 0.9797 - val_loss: 0.0418 - val_accuracy: 0.9821
# Epoch 47/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0496 - accuracy: 0.9799 - val_loss: 0.0417 - val_accuracy: 0.9821
# Epoch 48/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0498 - accuracy: 0.9799 - val_loss: 0.0408 - val_accuracy: 0.9822
# Epoch 49/50
# 2969/2969 [==============================] - 29s 10ms/step - loss: 0.0500 - accuracy: 0.9798 - val_loss: 0.0405 - val_accuracy: 0.9825
# Epoch 50/50
# 2969/2969 [==============================] - 28s 9ms/step - loss: 0.0498 - accuracy: 0.9798 - val_loss: 0.0404 - val_accuracy: 0.9825
# 5938/5938 [==============================] - 13s 2ms/step
# Client 3 - Metrics after Local Epoch 1: [0.9824838417650897, 0.9854476900590989, 0.9794311459188615, 0.9824302065295435, 0.9990059465666118, 0.9855365376113181, 0.9649676835301796, 0.9649856690079113, array([[93624,  1374],
#        [ 1954, 93044]])]
